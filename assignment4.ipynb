# %% [markdown]
# ## Google_Play-Store

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")

# %%
from google.colab import files
uploaded = files.upload()

# %%
import io
gpt_data = pd.read_csv(io.BytesIO(uploaded['google-play-store.csv']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f0ad0daa7e4b> in <module>()
#       1 import io
# ----> 2 gpt_data = pd.read_csv(io.BytesIO(uploaded['google-play-store.csv']))
#
# NameError: name 'pd' is not defined

# %%
gpt_data.head()

# %%
gpt_data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
colab
gpt_data[gpt_data.duplicated()]
# Out:
#                                                      App  ...         Android Ver
# 229                         Quick PDF Scanner + OCR FREE  ...        4.0.3 and up
# 236                                                  Box  ...  Varies with device
# 239                                   Google My Business  ...          4.4 and up
# 256                                  ZOOM Cloud Meetings  ...          4.0 and up
# 261                            join.me - Simple Meetings  ...          4.4 and up
# 265                                                  Box  ...  Varies with device
# 266                                             Zenefits  ...          4.1 and up
# 267                                           Google Ads  ...        4.0.3 and up
# 268                                   Google My Business  ...          4.4 and up
# 269                                                Slack  ...  Varies with device
# 270                                   FreshBooks Classic  ...          4.2 and up
# 271                                        Insightly CRM  ...          5.0 and up
# 272          QuickBooks Accounting: Invoicing & Expenses  ...          4.1 and up
# 273                       HipChat - Chat Built for Teams  ...          4.1 and up
# 274                             Xero Accounting Software  ...  Varies with device
# 275              MailChimp - Email, Marketing Automation  ...          5.0 and up
# 276                 Crew - Free Messaging and Scheduling  ...        4.0.3 and up
# 277                        Asana: organize team projects  ...          5.0 and up
# 278                                     Google Analytics  ...          4.4 and up
# 279                                      AdWords Express  ...          4.0 and up
# 280                          Accounting App - Zoho Books  ...          4.1 and up
# 281                       Invoice & Time Tracking - Zoho  ...          4.1 and up
# 282                            join.me - Simple Meetings  ...          4.4 and up
# 283    Invoice 2go — Professional Invoices and Estimates  ...          4.1 and up
# 284     SignEasy | Sign and Fill PDF and other Documents  ...  Varies with device
# 286                            Genius Scan - PDF Scanner  ...  Varies with device
# 287                       Tiny Scanner - PDF Scanner App  ...          3.0 and up
# 288                         Fast Scanner : Free PDF Scan  ...          4.1 and up
# 289                     Mobile Doc Scanner (MDScan) Lite  ...          4.1 and up
# 290        TurboScan: scan documents and receipts in PDF  ...          4.0 and up
# ...                                                  ...  ...                 ...
# 4234                       Skype - free IM & video calls  ...  Varies with device
# 4441                                              O-Star  ...          4.3 and up
# 5147                                         Maricopa AH  ...        4.0.3 and up
# 5537                         Houzz Interior Design Ideas  ...  Varies with device
# 5958                                  Anthem BC Anywhere  ...          4.4 and up
# 5989                                PMHNP-BC Pocket Prep  ...          4.4 and up
# 6584                                  iBP Blood Pressure  ...          2.2 and up
# 6585                                      Blood Pressure  ...          4.1 and up
# 6590                            Blood Pressure(BP) Diary  ...        4.0.3 and up
# 6593                   BP Journal - Blood Pressure Diary  ...          4.4 and up
# 6594                              Blood Pressure Monitor  ...          4.4 and up
# 6595                            Blood Pressure Companion  ...          4.1 and up
# 6598                                 Free Blood Pressure  ...        4.0.3 and up
# 6911                               Beautiful Widgets Pro  ...          2.3 and up
# 7030                         Elmo Calls by Sesame Street  ...          2.3 and up
# 7035                              420 BZ Budeze Delivery  ...          4.1 and up
# 7628                                           Brit + Co  ...          4.0 and up
# 7885                     CT Scan Cross Sectional Anatomy  ...          4.1 and up
# 8628                                         Google Docs  ...  Varies with device
# 8630   Any.do: To-do list, Calendar, Reminders & Planner  ...  Varies with device
# 8632                                Notepad & To do list  ...        2.3.3 and up
# 8635     Polaris Office - Word, Docs, Sheets, Slide, PDF  ...          4.1 and up
# 8636                                         Google Keep  ...  Varies with device
# 8639                         Do It Later: Tasks & To-Dos  ...  Varies with device
# 8642                              To-Do Calendar Planner  ...  Varies with device
# 8643                      Wunderlist: To-Do List & Tasks  ...  Varies with device
# 8654     TickTick: To Do List with Reminder, Day Planner  ...  Varies with device
# 8658                             ColorNote Notepad Notes  ...  Varies with device
# 10049          Airway Ex - Intubate. Anesthetize. Train.  ...          5.0 and up
# 10768                                               AAFP  ...          5.0 and up
#
# [483 rows x 13 columns]

# %%
gpt_data= gpt_data.drop_duplicates(subset='App')

# %%
gpt_data.dropna(inplace=True,subset=['Type','Content Rating','Current Ver','Android Ver'])

# %%
gpt_data.fillna(0,inplace=True)

# %%
gpt_data[gpt_data['Rating'] == 0].head()
# Out:
#                                      App  ... Android Ver
# 23                Mcqueen Coloring pages  ...  4.1 and up
# 113            Wrinkles and rejuvenation  ...  3.0 and up
# 123               Manicure - nail design  ...  4.1 and up
# 126         Skin Care and Natural Beauty  ...  4.1 and up
# 129  Secrets of beauty, youth and health  ...  2.3 and up
#
# [5 rows x 13 columns]

# %%
gpt_data['Rating'].describe().T
# Out:
# count    9648.000000
# mean        3.542651
# std         1.574478
# min         0.000000
# 25%         3.600000
# 50%         4.200000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
sns.distplot(gpt_data[gpt_data['Rating']!=0]['Rating'])

# %%
sns.countplot(data=gpt_data,x='Content Rating')

# %%
sns.countplot(data=gpt_data,x='Type')

# %%
temp = gpt_data['Genres'].value_counts()
temp = temp.reset_index()
temp = temp[temp['Genres'] > 100]
temp.head()
# Out:
#            index  Genres
# 0          Tools     824
# 1  Entertainment     560
# 2      Education     509
# 3       Business     420
# 4        Medical     395

# %%
d = pd.DatetimeIndex(gpt_data['Last Updated'])
gpt_data['Year'] = d.year
gpt_data[(gpt_data['Installs'] != '1,000,000,000+') & (gpt_data['Genres'] == 'Tools') & (gpt_data['Rating'] >= 4.5) & (gpt_data['Year'] == 2018)]['App'][0:10]
# Out:
# 3239    Cache Cleaner-DU Speed Booster (booster & clea...
# 3240                                   Moto Suggestions ™
# 3246                                         File Manager
# 3248    Calculator - free calculator, multi calculator...
# 3249                                  ASUS Sound Recorder
# 3253                                           ZenUI Help
# 3255                           SHAREit - Transfer & Share
# 3256                        ZenUI Keyboard – Emoji, Theme
# 3257      Files Go by Google: Free up space on your phone
# 3285                         I Can't Wake Up! Alarm Clock
# Name: App, dtype: object
